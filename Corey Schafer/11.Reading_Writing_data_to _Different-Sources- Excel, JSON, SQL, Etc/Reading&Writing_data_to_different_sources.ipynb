# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv',index_col = 'Respondent')  
schema_df = pd.read_csv('data/survey_results_schema.csv',index_col ='Column')

# %%
pd.set_option('display.max_columns',85)

pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
filt =(df['Country']=='India')
india_df =df.loc[filt]
india_df.head(30)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# 68                  I am a developer by profession      Yes
# 75                  I am a developer by profession      Yes
# 78                  I am a developer by profession       No
# 83                  I am a developer by profession      Yes
# 89          I am a student who is learning to code      Yes
# 90                  I am a developer by profession      Yes
# 99          I am a student who is learning to code      Yes
# 104                 I am a developer by profession      Yes
# 121         I am a student who is learning to code      Yes
# ...

# %%
# now exporting this filtered data to a new csv file using .to_csv() method
india_df.to_csv('data/modified.csv')  # makes a new csv fiile on that location

# %%
india_df.to_csv('data/modified.tsv',sep = '\t')

# %% [markdown]
# # Working on Excel files

# %% [markdown]
# # --> requirements:-
# #    1) pip install xlwt
# #    2) pip install openpyxl
# #    3) pip install xlrd

# %%
india_df.to_excel('data/modified.xlsx')  # writing india_df to a excel file

# %%
# reading an excel file that we just created

test = pd.read_excel('data/modified.xlsx', index_col='Respondent')

# %%
test.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %% [markdown]
# # Working on JSON file format :--

# %%
india_df.to_json('data/modified1.json')   # the file created looks like the dictionary

# %%
# making a file that looks like the list

india_df.to_json('data/modified2.json',orient ='records',lines = True)

# %%
# reading json file

test = pd.read_json('data/modified2.json',orient ='records',lines = True)

# %%
test.head()
# Out:
#                                MainBranch Hobbyist  \
# 0             I code primarily as a hobby      Yes
# 1          I am a developer by profession      Yes
# 2  I am a student who is learning to code      Yes
# 3          I am a developer by profession      Yes
# 4          I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0     Less than once per year
# 1  Once a month or more often
# 2                       Never
# 3  Once a month or more often
# 4                       Never
#
#                                           OpenSource  \
# 0  OSS is, on average, of HIGHER quality than pro...
# 1  OSS is, on average, of HIGHER quality than pro...
# 2  OSS is, on average, of HIGHER quality than pro...
# 3  OSS is, on average, of LOWER quality than prop...
# 4                                               None
#
#                            Employment Country         Student  \
# 0  Not employed, but looking for work   India            None
# ...

# %% [markdown]
# # Working on SQL databases

# %% [markdown]
# # Requirements :-
#
# # 1)  pip install SQLAlchemy
# # 2)  pip install pymysql
# # 3)  pip install psycopg2-binary

# %%
from sqlalchemy import create_engine
